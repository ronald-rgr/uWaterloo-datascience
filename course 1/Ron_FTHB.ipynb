# %% [markdown]
# ---
#
# Home ownership data:
#
# This notebook contains **Analyze first-time home buyers by CMA**
#
# In this part we will work through the following topics:
#
# 1.	Age of first-time home owners
# 2.	Type of home for first-time home buyers
# 3.	Marital stats of first-time home buyers
# 4.	Location by city of first-time home buyers

# %%
#Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
# Let's create a dataframe using the dbFTHB2018.csv file
df_fthb=pd.read_csv('csv/dbFTHB2018.csv',index_col=None)

# %%
# We should display the first 5 rows to get a sense of the data
df_fthb.head()
# Out:
#    REF_DATE               GEO         DGUID  \
# 0      2018  Montréal, Quebec  2016S0503462
# 1      2018  Montréal, Quebec  2016S0503462
# 2      2018  Montréal, Quebec  2016S0503462
# 3      2018  Montréal, Quebec  2016S0503462
# 4      2018  Montréal, Quebec  2016S0503462
#
#                        Dwelling tenure         Selected housing indicators  \
# 0  Owner who is a first-time homebuyer  Total, structural type of dwelling
# 1  Owner who is a first-time homebuyer  Total, structural type of dwelling
# 2  Owner who is a first-time homebuyer               Single-detached house
# 3  Owner who is a first-time homebuyer               Single-detached house
# 4  Owner who is a first-time homebuyer                 Semi-detached house
#
#                  Statistics      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0      Number of households   Number     223         units          0
# 1  Percentage of households  Percent     239         units          0
# 2      Number of households   Number     223         units          0
# 3  Percentage of households  Percent     239         units          0
# 4      Number of households   Number     223         units          0
#
#         VECTOR COORDINATE     VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  v1110604520   64.3.1.1  150300.0      B     NaN         NaN         0
# 1  v1110604523   64.3.1.4     100.0    NaN     NaN         NaN         1
# 2  v1110604526   64.3.2.1   57200.0      B     NaN         NaN         0
# 3  v1110604529   64.3.2.4      38.0    NaN     NaN         NaN         1
# 4  v1110604532   64.3.3.1   13400.0      D     NaN         NaN         0

# %%
df_fthb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   REF_DATE                     912 non-null    int64
#  1   GEO                          912 non-null    object
#  2   DGUID                        912 non-null    object
#  3   Dwelling tenure              912 non-null    object
#  4   Selected housing indicators  912 non-null    object
#  5   Statistics                   912 non-null    object
#  6   UOM                          912 non-null    object
#  7   UOM_ID                       912 non-null    int64
#  8   SCALAR_FACTOR                912 non-null    object
#  9   SCALAR_ID                    912 non-null    int64
#  10  VECTOR                       912 non-null    object
#  11  COORDINATE                   912 non-null    object
#  12  VALUE                        832 non-null    float64
#  13  STATUS                       514 non-null    object
#  14  SYMBOL                       0 non-null      float64
#  15  TERMINATED                   0 non-null      float64
#  16  DECIMALS                     912 non-null    int64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 121.2+ KB

# %%
df_fthb.describe()
# Out:
#        REF_DATE     UOM_ID  SCALAR_ID          VALUE  SYMBOL  TERMINATED  \
# count     912.0  912.00000      912.0     832.000000     0.0         0.0
# mean     2018.0  231.00000        0.0   35165.031130     NaN         NaN
# std         0.0    8.00439        0.0  100196.941321     NaN         NaN
# min      2018.0  223.00000        0.0       0.300000     NaN         NaN
# 25%      2018.0  223.00000        0.0      16.575000     NaN         NaN
# 50%      2018.0  231.00000        0.0     600.000000     NaN         NaN
# 75%      2018.0  239.00000        0.0   25475.000000     NaN         NaN
# max      2018.0  239.00000        0.0  791900.000000     NaN         NaN
#
#          DECIMALS
# count  912.000000
# mean     0.500000
# std      0.500274
# min      0.000000
# 25%      0.000000
# 50%      0.500000
# 75%      1.000000
# max      1.000000

# %%
# Now let's check if there's any missing data
df_fthb.isnull().sum()
# Out:
# REF_DATE                         0
# GEO                              0
# DGUID                            0
# Dwelling tenure                  0
# Selected housing indicators      0
# Statistics                       0
# UOM                              0
# UOM_ID                           0
# SCALAR_FACTOR                    0
# SCALAR_ID                        0
# VECTOR                           0
# COORDINATE                       0
# VALUE                           80
# STATUS                         398
# SYMBOL                         912
# TERMINATED                     912
# DECIMALS                         0
# dtype: int64

# %%
#Let's check cities
df_fthb.groupby('GEO')['Statistics'].agg(['count', 'size', 'nunique']).stack()
# Out:
# GEO
# Calgary, Alberta                 count      152
#                                  size       152
#                                  nunique      2
# Edmonton, Alberta                count      152
#                                  size       152
#                                  nunique      2
# Montréal, Quebec                 count      152
#                                  size       152
#                                  nunique      2
# Ottawa-Gatineau, Ontario/Quebec  count      152
#                                  size       152
#                                  nunique      2
# Toronto, Ontario                 count      152
#                                  size       152
#                                  nunique      2
# Vancouver, British Columbia      count      152
#                                  size       152
#                                  nunique      2
# dtype: int64

# %%
df_fthb["GEO"].unique()
# Out:
# array(['Montréal, Quebec', 'Ottawa-Gatineau, Ontario/Quebec',
#        'Toronto, Ontario', 'Calgary, Alberta', 'Edmonton, Alberta',
#        'Vancouver, British Columbia'], dtype=object)

# %%
#Unique values for Dwelling tenure
df_fthb.groupby('Dwelling tenure')['Statistics'].agg(['count', 'size', 'nunique']).stack()
# Out:
# Dwelling tenure
# Owner who is a first-time homebuyer  count      456
#                                      size       456
#                                      nunique      2
# Renter                               count      456
#                                      size       456
#                                      nunique      2
# dtype: int64

# %%
#Unique values for Selected housing indicators
df_fthb["Selected housing indicators"].unique()
# Out:
# array(['Total, structural type of dwelling', 'Single-detached house',
#        'Semi-detached house', 'Row house',
#        'Apartment or flat in a duplex',
#        'Apartment in a building that has five or more storeys',
#        'Apartment in a building that has fewer than five storeys',
#        'Other single-attached house', 'Moveable dwelling',
#        'Total, condominium status', 'Condominium', 'Not condominium',
#        'Total, satisfaction with dwelling',
#        'Very satisfied with dwelling', 'Satisfied with dwelling',
#        'Neither satisfied nor dissatisfied with dwelling',
#        'Dissatisfied with dwelling', 'Very dissatisfied with dwelling',
#        'Total, satisfaction with neighbourhood',
#        'Very satisfied with neighbourhood',
#        'Satisfied with neighbourhood',
#        'Neither satisfied nor dissatisfied with neighbourhood',
#        'Dissatisfied with neighbourhood',
#        'Very dissatisfied with neighbourhood',
#        'Moved because the household was forced to move by a landlord, a bank or other financial institution or the government',
#        'Moved due to a natural disaster or fire',
#        'Moved for a new job or job transfer', 'Moved for a new school',
#        'Moved to form own household', 'Moved to be closer to family',
#        'Moved because of a change in household or family size',
#        'Moved to reduce commuting time',
#        'Moved to upgrade to a larger dwelling or better quality dwelling',
#        'Moved to reduce housing costs',
#        'Moved to be in a more desirable neighbourhood',
#        'Moved for personal health reasons', 'Moved to become a homeowner',
#        'Moved for another reason'], dtype=object)

# %%
#Dropping the empty columns
df_fthb2 = df_fthb.drop(['SYMBOL', 'TERMINATED'], axis=1)

#Dropping columns that do not contribute information for the analysis
df_fthb2.drop(['REF_DATE','DGUID', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 
                              'COORDINATE', 'STATUS', 'DECIMALS'], axis=1, inplace=True)

# %%
df_fthb2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   GEO                          912 non-null    object
#  1   Dwelling tenure              912 non-null    object
#  2   Selected housing indicators  912 non-null    object
#  3   Statistics                   912 non-null    object
#  4   VALUE                        832 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 35.8+ KB

# %%
#Selecting rows of data which contain information on Toronto, Vancouver, and Calgary markets
df_fthb2 =  df_fthb2.loc[df_fthb2['GEO'].isin(['Toronto, Ontario','Vancouver, British Columbia','Calgary, Alberta'])]
df_fthb2
# Out:
#                              GEO                      Dwelling tenure  \
# 304             Toronto, Ontario  Owner who is a first-time homebuyer
# 305             Toronto, Ontario  Owner who is a first-time homebuyer
# 306             Toronto, Ontario  Owner who is a first-time homebuyer
# 307             Toronto, Ontario  Owner who is a first-time homebuyer
# 308             Toronto, Ontario  Owner who is a first-time homebuyer
# ..                           ...                                  ...
# 907  Vancouver, British Columbia                               Renter
# 908  Vancouver, British Columbia                               Renter
# 909  Vancouver, British Columbia                               Renter
# 910  Vancouver, British Columbia                               Renter
# 911  Vancouver, British Columbia                               Renter
#
#             Selected housing indicators                Statistics     VALUE
# 304  Total, structural type of dwelling      Number of households  208800.0
# 305  Total, structural type of dwelling  Percentage of households     100.0
# 306               Single-detached house      Number of households   55100.0
# 307               Single-detached house  Percentage of households      26.0
# 308                 Semi-detached house      Number of households   21500.0
# ..                                  ...                       ...       ...
# 907   Moved for personal health reasons  Percentage of households       5.8
# 908         Moved to become a homeowner      Number of households    5400.0
# 909         Moved to become a homeowner  Percentage of households       1.4
# 910            Moved for another reason      Number of households    6400.0
# 911            Moved for another reason  Percentage of households       1.7
#
# [456 rows x 5 columns]

# %%
#rename columns
df_fthb2 = df_fthb2.rename(columns={"GEO": "City", "Dwelling tenure": "Tenure", "Selected housing indicators": "Indicator", "VALUE": "Value"})
df_fthb2
# Out:
#                             City                               Tenure  \
# 304             Toronto, Ontario  Owner who is a first-time homebuyer
# 305             Toronto, Ontario  Owner who is a first-time homebuyer
# 306             Toronto, Ontario  Owner who is a first-time homebuyer
# 307             Toronto, Ontario  Owner who is a first-time homebuyer
# 308             Toronto, Ontario  Owner who is a first-time homebuyer
# ..                           ...                                  ...
# 907  Vancouver, British Columbia                               Renter
# 908  Vancouver, British Columbia                               Renter
# 909  Vancouver, British Columbia                               Renter
# 910  Vancouver, British Columbia                               Renter
# 911  Vancouver, British Columbia                               Renter
#
#                               Indicator                Statistics     Value
# 304  Total, structural type of dwelling      Number of households  208800.0
# 305  Total, structural type of dwelling  Percentage of households     100.0
# 306               Single-detached house      Number of households   55100.0
# 307               Single-detached house  Percentage of households      26.0
# 308                 Semi-detached house      Number of households   21500.0
# ..                                  ...                       ...       ...
# 907   Moved for personal health reasons  Percentage of households       5.8
# 908         Moved to become a homeowner      Number of households    5400.0
# 909         Moved to become a homeowner  Percentage of households       1.4
# 910            Moved for another reason      Number of households    6400.0
# 911            Moved for another reason  Percentage of households       1.7
#
# [456 rows x 5 columns]

# %%
df_profile_movedto =  df_fthb2.loc[df_fthb2['Tenure'].isin(['Owner who is a first-time homebuyer'])]
df_profile_movedto
# Out:
#                             City                               Tenure  \
# 304             Toronto, Ontario  Owner who is a first-time homebuyer
# 305             Toronto, Ontario  Owner who is a first-time homebuyer
# 306             Toronto, Ontario  Owner who is a first-time homebuyer
# 307             Toronto, Ontario  Owner who is a first-time homebuyer
# 308             Toronto, Ontario  Owner who is a first-time homebuyer
# ..                           ...                                  ...
# 831  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 832  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 833  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 834  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 835  Vancouver, British Columbia  Owner who is a first-time homebuyer
#
#                               Indicator                Statistics     Value
# 304  Total, structural type of dwelling      Number of households  208800.0
# 305  Total, structural type of dwelling  Percentage of households     100.0
# 306               Single-detached house      Number of households   55100.0
# 307               Single-detached house  Percentage of households      26.0
# 308                 Semi-detached house      Number of households   21500.0
# ..                                  ...                       ...       ...
# 831   Moved for personal health reasons  Percentage of households       2.1
# 832         Moved to become a homeowner      Number of households   54600.0
# 833         Moved to become a homeowner  Percentage of households      57.0
# 834            Moved for another reason      Number of households     800.0
# 835            Moved for another reason  Percentage of households       NaN
#
# [228 rows x 5 columns]

# %%
df_profile_movedto =  df_profile_movedto.loc[df_fthb2['Statistics'].isin(['Percentage of households'])]
df_profile_MovedTo = df_profile_movedto.dropna()
df_profile_movedto
# Out:
#                             City                               Tenure  \
# 305             Toronto, Ontario  Owner who is a first-time homebuyer
# 307             Toronto, Ontario  Owner who is a first-time homebuyer
# 309             Toronto, Ontario  Owner who is a first-time homebuyer
# 311             Toronto, Ontario  Owner who is a first-time homebuyer
# 313             Toronto, Ontario  Owner who is a first-time homebuyer
# ..                           ...                                  ...
# 827  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 829  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 831  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 833  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 835  Vancouver, British Columbia  Owner who is a first-time homebuyer
#
#                                          Indicator                Statistics  \
# 305             Total, structural type of dwelling  Percentage of households
# 307                          Single-detached house  Percentage of households
# 309                            Semi-detached house  Percentage of households
# 311                                      Row house  Percentage of households
# 313                  Apartment or flat in a duplex  Percentage of households
# ..                                             ...                       ...
# 827                  Moved to reduce housing costs  Percentage of households
# 829  Moved to be in a more desirable neighbourhood  Percentage of households
# 831              Moved for personal health reasons  Percentage of households
# 833                    Moved to become a homeowner  Percentage of households
# 835                       Moved for another reason  Percentage of households
#
#      Value
# 305  100.0
# 307   26.0
# 309   10.3
# 311    8.6
# 313    1.6
# ..     ...
# 827    5.2
# 829   16.6
# 831    2.1
# 833   57.0
# 835    NaN
#
# [114 rows x 5 columns]

# %%
df_profile_movedto =  df_profile_movedto.loc[df_profile_movedto['Indicator'].isin([
    'Moved because of a change in household or family size',
    'Moved because the household was forced to move by a landlord, a bank or other financial institution or the government',
    'Moved for a new job or job transfer',
    'Moved for a new school',
    'Moved for personal health reasons',
    'Moved to be closer to family',
    'Moved to be in a more desirable neighbourhood',
    'Moved to become a homeowner',
    'Moved to form own household',
    'Moved to reduce commuting time',
    'Moved to reduce housing costs',
    'Moved to upgrade to a larger dwelling or better quality dwelling'])]
df_profile_movedto
# Out:
#                             City                               Tenure  \
# 353             Toronto, Ontario  Owner who is a first-time homebuyer
# 357             Toronto, Ontario  Owner who is a first-time homebuyer
# 359             Toronto, Ontario  Owner who is a first-time homebuyer
# 361             Toronto, Ontario  Owner who is a first-time homebuyer
# 363             Toronto, Ontario  Owner who is a first-time homebuyer
# 365             Toronto, Ontario  Owner who is a first-time homebuyer
# 367             Toronto, Ontario  Owner who is a first-time homebuyer
# 369             Toronto, Ontario  Owner who is a first-time homebuyer
# 371             Toronto, Ontario  Owner who is a first-time homebuyer
# 373             Toronto, Ontario  Owner who is a first-time homebuyer
# 375             Toronto, Ontario  Owner who is a first-time homebuyer
# 377             Toronto, Ontario  Owner who is a first-time homebuyer
# 505             Calgary, Alberta  Owner who is a first-time homebuyer
# 509             Calgary, Alberta  Owner who is a first-time homebuyer
# 511             Calgary, Alberta  Owner who is a first-time homebuyer
# 513             Calgary, Alberta  Owner who is a first-time homebuyer
# 515             Calgary, Alberta  Owner who is a first-time homebuyer
# 517             Calgary, Alberta  Owner who is a first-time homebuyer
# 519             Calgary, Alberta  Owner who is a first-time homebuyer
# 521             Calgary, Alberta  Owner who is a first-time homebuyer
# 523             Calgary, Alberta  Owner who is a first-time homebuyer
# 525             Calgary, Alberta  Owner who is a first-time homebuyer
# 527             Calgary, Alberta  Owner who is a first-time homebuyer
# 529             Calgary, Alberta  Owner who is a first-time homebuyer
# 809  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 813  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 815  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 817  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 819  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 821  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 823  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 825  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 827  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 829  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 831  Vancouver, British Columbia  Owner who is a first-time homebuyer
# 833  Vancouver, British Columbia  Owner who is a first-time homebuyer
#
#                                              Indicator  \
# 353  Moved because the household was forced to move...
# 357                Moved for a new job or job transfer
# 359                             Moved for a new school
# 361                        Moved to form own household
# 363                       Moved to be closer to family
# 365  Moved because of a change in household or fami...
# 367                     Moved to reduce commuting time
# 369  Moved to upgrade to a larger dwelling or bette...
# 371                      Moved to reduce housing costs
# 373      Moved to be in a more desirable neighbourhood
# 375                  Moved for personal health reasons
# 377                        Moved to become a homeowner
# 505  Moved because the household was forced to move...
# 509                Moved for a new job or job transfer
# 511                             Moved for a new school
# 513                        Moved to form own household
# 515                       Moved to be closer to family
# 517  Moved because of a change in household or fami...
# 519                     Moved to reduce commuting time
# 521  Moved to upgrade to a larger dwelling or bette...
# 523                      Moved to reduce housing costs
# 525      Moved to be in a more desirable neighbourhood
# 527                  Moved for personal health reasons
# 529                        Moved to become a homeowner
# 809  Moved because the household was forced to move...
# 813                Moved for a new job or job transfer
# 815                             Moved for a new school
# 817                        Moved to form own household
# 819                       Moved to be closer to family
# 821  Moved because of a change in household or fami...
# 823                     Moved to reduce commuting time
# 825  Moved to upgrade to a larger dwelling or bette...
# 827                      Moved to reduce housing costs
# 829      Moved to be in a more desirable neighbourhood
# 831                  Moved for personal health reasons
# 833                        Moved to become a homeowner
#
#                    Statistics  Value
# 353  Percentage of households    5.2
# 357  Percentage of households    7.4
# 359  Percentage of households    4.0
# 361  Percentage of households   22.0
# 363  Percentage of households    3.6
# 365  Percentage of households    8.4
# 367  Percentage of households    7.6
# 369  Percentage of households   23.0
# 371  Percentage of households    7.7
# 373  Percentage of households   13.3
# 375  Percentage of households    NaN
# 377  Percentage of households   68.0
# 505  Percentage of households    1.8
# 509  Percentage of households    9.8
# 511  Percentage of households    3.1
# 513  Percentage of households   24.0
# 515  Percentage of households    6.5
# 517  Percentage of households   15.1
# 519  Percentage of households    9.4
# 521  Percentage of households   33.0
# 523  Percentage of households    5.9
# 525  Percentage of households   25.0
# 527  Percentage of households    NaN
# 529  Percentage of households   78.0
# 809  Percentage of households    6.7
# 813  Percentage of households    3.8
# 815  Percentage of households    2.3
# 817  Percentage of households   21.0
# 819  Percentage of households    2.5
# 821  Percentage of households   14.3
# 823  Percentage of households    7.5
# 825  Percentage of households   22.0
# 827  Percentage of households    5.2
# 829  Percentage of households   16.6
# 831  Percentage of households    2.1
# 833  Percentage of households   57.0

# %%
percentaje_house_holds_analysis = pd.crosstab(df_profile_movedto['Indicator']
                                             ,df_profile_movedto['Tenure']
                                             ,df_profile_movedto['Value'],aggfunc='mean').round(1)
percentaje_house_holds_analysis
# Out:
# Tenure                                              Owner who is a first-time homebuyer
# Indicator
# Moved because of a change in household or famil...                                 12.6
# Moved because the household was forced to move ...                                  4.6
# Moved for a new job or job transfer                                                 7.0
# Moved for a new school                                                              3.1
# Moved for personal health reasons                                                   2.1
# Moved to be closer to family                                                        4.2
# Moved to be in a more desirable neighbourhood                                      18.3
# Moved to become a homeowner                                                        67.7
# Moved to form own household                                                        22.3
# Moved to reduce commuting time                                                      8.2
# Moved to reduce housing costs                                                       6.3
# Moved to upgrade to a larger dwelling or better...                                 26.0

# %%
#Let's try to visualize some of these

# %%
ax = sns.barplot(x='Value', y='Indicator', data=df_profile_movedto)
ax.set_xlabel('Percentage of households')
ax.set_ylabel('Reason')
ax.set_title('Reasons first-time homebuyers moved')
# Out:
# Text(0.5, 1.0, 'Reasons first-time homebuyers moved')

# %%
ax_households = percentaje_house_holds_analysis.plot(kind='bar', 
                                                     #width, color = 'gray', alpha = 0.7, 
                                                     legend = False, figsize=(10,8))
ax_households.set(title = 'Reasons first-time homebuyers moved', ylabel = 'Percentaje', xlabel = "Reason")
plt.show();

# %%
#We can use the crosstab function to pivot Selected housing indicators and Dwelling tenure
Housing_Indicator_Analysis = pd.crosstab(df_fthb2['Indicator'],df_fthb2['Tenure'],df_fthb2['Value'],aggfunc='mean').round(1)
Housing_Indicator_Analysis
# Out:
# Tenure                                              Owner who is a first-time homebuyer  \
# Indicator
# Apartment in a building that has fewer than fiv...                               9009.0
# Apartment in a building that has five or more s...                              17794.1
# Apartment or flat in a duplex                                                    1084.2
# Condominium                                                                     30089.7
# Dissatisfied with dwelling                                                       2262.8
# Dissatisfied with neighbourhood                                                  1768.1
# Moveable dwelling                                                                   NaN
# Moved because of a change in household or famil...                               6939.6
# Moved because the household was forced to move ...                               3069.0
# Moved due to a natural disaster or fire                                           200.0
# Moved for a new job or job transfer                                              4286.8
# Moved for a new school                                                           2118.2
# Moved for another reason                                                          533.3
# Moved for personal health reasons                                                1500.5
# Moved to be closer to family                                                     2385.4
# Moved to be in a more desirable neighbourhood                                   10109.2
# Moved to become a homeowner                                                     41517.2
# Moved to form own household                                                     13794.5
# Moved to reduce commuting time                                                   4904.1
# Moved to reduce housing costs                                                    4153.1
# Moved to upgrade to a larger dwelling or better...                              15213.0
# Neither satisfied nor dissatisfied with dwelling                                13009.8
# Neither satisfied nor dissatisfied with neighbo...                               9824.5
# Not condominium                                                                 31927.0
# Other single-attached house                                                       733.6
# Row house                                                                        7773.8
# Satisfied with dwelling                                                         29691.3
# Satisfied with neighbourhood                                                    31441.3
# Semi-detached house                                                              5523.4
# Single-detached house                                                           18099.3
# Total, condominium status                                                       62016.7
# Total, satisfaction with dwelling                                               62016.7
# Total, satisfaction with neighbourhood                                          62016.7
# Total, structural type of dwelling                                              62000.0
# Very dissatisfied with dwelling                                                  1000.0
# Very dissatisfied with neighbourhood                                             1566.7
# Very satisfied with dwelling                                                    17263.2
# Very satisfied with neighbourhood                                               18198.8
#
# Tenure                                                Renter
# Indicator
# Apartment in a building that has fewer than fiv...   58915.8
# Apartment in a building that has five or more s...  100684.5
# Apartment or flat in a duplex                        12453.3
# Condominium                                          46428.6
# Dissatisfied with dwelling                           21971.4
# Dissatisfied with neighbourhood                      13186.2
# Moveable dwelling                                      700.0
# Moved because of a change in household or famil...   40692.2
# Moved because the household was forced to move ...   24689.4
# Moved due to a natural disaster or fire               1233.6
# Moved for a new job or job transfer                  26306.2
# Moved for a new school                               12786.5
# Moved for another reason                              3267.5
# Moved for personal health reasons                    13086.1
# Moved to be closer to family                         16237.0
# Moved to be in a more desirable neighbourhood        42726.3
# Moved to become a homeowner                           2750.8
# Moved to form own household                          22338.6
# Moved to reduce commuting time                       20922.0
# Moved to reduce housing costs                        30207.3
# Moved to upgrade to a larger dwelling or better...   49428.5
# Neither satisfied nor dissatisfied with dwelling     45710.0
# Neither satisfied nor dissatisfied with neighbo...   30306.9
# Not condominium                                     168771.3
# Other single-attached house                           1100.0
# Row house                                            13771.1
# Satisfied with dwelling                             103341.0
# Satisfied with neighbourhood                         99922.8
# Semi-detached house                                   6118.4
# Single-detached house                                19472.5
# Total, condominium status                           215416.7
# Total, satisfaction with dwelling                   215416.7
# Total, satisfaction with neighbourhood              215450.0
# Total, structural type of dwelling                  215433.3
# Very dissatisfied with dwelling                       6384.5
# Very dissatisfied with neighbourhood                  3667.4
# Very satisfied with dwelling                         38009.7
# Very satisfied with neighbourhood                    68366.7

# %%
#Fill NA/NaN values with 0. Keep in mind that unit of the missing values is percentaje
#df_fthb2['VALUE'].fillna(0, inplace = True)

#Let's drop the rows where VALUE is missing
df_fthb2.dropna(subset=['Value'], inplace=True)
df_fthb2.isnull().sum()
# Out:
# City          0
# Tenure        0
# Indicator     0
# Statistics    0
# Value         0
# dtype: int64

# %%
#Okay. Let's do some analysis on the percentaje of households for first-time home buyers (FTHB)
percentaje_analysis = pd.crosstab(df_fthb2['Tenure'],df_fthb2['City'],df_fthb2['Value'],aggfunc='mean').round(1)
percentaje_analysis
# Out:
# City                                 Calgary, Alberta  Toronto, Ontario  \
# Tenure
# Owner who is a first-time homebuyer           10353.1           30605.5
# Renter                                        18422.5           99821.1
#
# City                                 Vancouver, British Columbia
# Tenure
# Owner who is a first-time homebuyer                      13421.4
# Renter                                                   47662.7

# %%
#Let's pull some basic stats for the percentaje of households, incl the mean, standard deviation, and distribution of data
df_fthb2.describe()
# Out:
#                Value
# count     420.000000
# mean    37558.916429
# std    101072.801029
# min         0.300000
# 25%        16.925000
# 50%       600.000000
# 75%     28100.000000
# max    776100.000000

# %%
#We can see that ...
#Let's try to visualize some of these insights
ax_provinces = percentaje_analysis[['Calgary, Alberta', 'Toronto, Ontario', 
                                    'Vancouver, British Columbia']].plot(kind='bar', 
                                                                         legend = True, figsize=(10,8))
ax_provinces.set(title = 'Percentaje of households',
       ylabel = 'Percentaje for 2018', xlabel = "Dwelling tenure")
plt.show();
