# %%
#Importing packages
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

#Importing visualization packages
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.ticker import ScalarFormatter

import seaborn as sns

# %%
#Importing the data as panda dataframe
df_mortgage = pd.read_csv('dbAvgMortgage1999-2016.csv')

df_mortgage.head()
# Out:
#    REF_DATE               GEO         DGUID                 Assets and debts  \
# 0      1999  Montréal, Quebec  2011S0503462  Mortgage on principal residence
# 1      2005  Montréal, Quebec  2011S0503462  Mortgage on principal residence
# 2      2012  Montréal, Quebec  2011S0503462  Mortgage on principal residence
# 3      2016  Montréal, Quebec  2011S0503462  Mortgage on principal residence
# 4      1999  Montréal, Quebec  2011S0503462  Mortgage on principal residence
#
#         Age group                               Economic family type  \
# 0        All ages  Economic families and persons not in an econom...
# 1        All ages  Economic families and persons not in an econom...
# 2        All ages  Economic families and persons not in an econom...
# 3        All ages  Economic families and persons not in an econom...
# 4  Under 65 years  Economic families and persons not in an econom...
#
#                                       Statistics Confidence intervals  \
# 0  Average value for those holding asset or debt             Estimate
# 1  Average value for those holding asset or debt             Estimate
# 2  Average value for those holding asset or debt             Estimate
# 3  Average value for those holding asset or debt             Estimate
# 4  Average value for those holding asset or debt             Estimate
#
#                      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID      VECTOR  \
# 0  2016 constant dollars     350         units          0  v114977559
# 1  2016 constant dollars     350         units          0  v114977559
# 2  2016 constant dollars     350         units          0  v114977559
# 3  2016 constant dollars     350         units          0  v114977559
# 4  2016 constant dollars     350         units          0  v114977577
#
#       COORDINATE     VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  15.20.1.1.6.1   95300.0    NaN     NaN         NaN         0
# 1  15.20.1.1.6.1  118700.0    NaN     NaN         NaN         0
# 2  15.20.1.1.6.1  160600.0    NaN     NaN         NaN         0
# 3  15.20.1.1.6.1  167000.0    NaN     NaN         NaN         0
# 4  15.20.2.1.6.1   97000.0    NaN     NaN         NaN         0

# %%
#Quick look at the data:

df_mortgage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   REF_DATE              140 non-null    int64
#  1   GEO                   140 non-null    object
#  2   DGUID                 140 non-null    object
#  3   Assets and debts      140 non-null    object
#  4   Age group             140 non-null    object
#  5   Economic family type  140 non-null    object
#  6   Statistics            140 non-null    object
#  7   Confidence intervals  140 non-null    object
#  8   UOM                   140 non-null    object
#  9   UOM_ID                140 non-null    int64
#  10  SCALAR_FACTOR         140 non-null    object
#  11  SCALAR_ID             140 non-null    int64
#  12  VECTOR                140 non-null    object
#  13  COORDINATE            140 non-null    object
#  14  VALUE                 103 non-null    float64
#  15  STATUS                40 non-null     object
#  16  SYMBOL                0 non-null      float64
#  17  TERMINATED            0 non-null      float64
#  18  DECIMALS              140 non-null    int64
# dtypes: float64(3), int64(4), object(12)
# memory usage: 20.9+ KB

# %%
#Checking for columns with only one unique value (they can be dropped since they hold one similar value for all rows):
for col in df_mortgage:
    print("Unique values in column", col, "are:", df_mortgage[col].unique())
# Out:
# Unique values in column REF_DATE are: [1999 2005 2012 2016]
# Unique values in column GEO are: ['Montréal, Quebec' 'Toronto, Ontario' 'Calgary, Alberta'
#  'Edmonton, Alberta' 'Vancouver, British Columbia']
# Unique values in column DGUID are: ['2011S0503462' '2011S0503535' '2011S0503825' '2011S0503835'
#  '2011S0503933']
# Unique values in column Assets and debts are: ['Mortgage on principal residence']
# Unique values in column Age group are: ['All ages' 'Under 65 years' 'Under 35 years' '35 to 44 years'
#  '45 to 54 years' '55 to 64 years' '65 years and older']
# Unique values in column Economic family type are: ['Economic families and persons not in an economic family']
# Unique values in column Statistics are: ['Average value for those holding asset or debt']
# Unique values in column Confidence intervals are: ['Estimate']
# Unique values in column UOM are: ['2016 constant dollars']
# Unique values in column UOM_ID are: [350]
# Unique values in column SCALAR_FACTOR are: ['units']
# Unique values in column SCALAR_ID are: [0]
# Unique values in column VECTOR are: ['v114977559' 'v114977577' 'v114977595' 'v114977613' 'v114977631'
#  'v114977649' 'v114977667' 'v114980961' 'v114980979' 'v114980997'
#  'v114981015' 'v114981033' 'v114981051' 'v114981069' 'v114987765'
#  'v114987783' 'v114987801' 'v114987819' 'v114987837' 'v114987855'
#  'v114987873' 'v114991167' 'v114991185' 'v114991203' 'v114991221'
#  'v114991239' 'v114991257' 'v114991275' 'v114994569' 'v114994587'
#  'v114994605' 'v114994623' 'v114994641' 'v114994659' 'v114994677']
# Unique values in column COORDINATE are: ['15.20.1.1.6.1' '15.20.2.1.6.1' '15.20.3.1.6.1' '15.20.4.1.6.1'
#  '15.20.5.1.6.1' '15.20.6.1.6.1' '15.20.7.1.6.1' '16.20.1.1.6.1'
#  '16.20.2.1.6.1' '16.20.3.1.6.1' '16.20.4.1.6.1' '16.20.5.1.6.1'
#  '16.20.6.1.6.1' '16.20.7.1.6.1' '18.20.1.1.6.1' '18.20.2.1.6.1'
#  '18.20.3.1.6.1' '18.20.4.1.6.1' '18.20.5.1.6.1' '18.20.6.1.6.1'
#  '18.20.7.1.6.1' '19.20.1.1.6.1' '19.20.2.1.6.1' '19.20.3.1.6.1'
#  '19.20.4.1.6.1' '19.20.5.1.6.1' '19.20.6.1.6.1' '19.20.7.1.6.1'
#  '20.20.1.1.6.1' '20.20.2.1.6.1' '20.20.3.1.6.1' '20.20.4.1.6.1'
#  '20.20.5.1.6.1' '20.20.6.1.6.1' '20.20.7.1.6.1']
# Unique values in column VALUE are: [ 95300. 118700. 160600. 167000.  97000. 122200. 163100. 170800. 110700.
#      nan 198200. 206500.  99500. 147200. 179200. 191700.  88500.  98200.
#  134900. 165400.  79700. 128800. 112400. 112300. 156600. 194000. 226000.
#  299300. 157900. 199600. 232400. 304200. 193800. 273200. 337300. 152000.
#  225500. 266900. 328500. 189200. 194500. 283700. 121200. 140000. 182000.
#  266800. 217700. 121900. 140500. 243800. 122500. 140600. 245100. 271600.
#  141700. 296900. 124200. 278500. 273100. 107800. 116000. 187600. 268200.
#  236500.  92900. 136900. 211300. 248100.  94000. 137300. 208800. 255800.
#  113000. 274300.  92400. 255700.  87000. 173900. 246900. 232300. 176300.
#  218100. 292700. 320000. 180600. 220700. 294700. 331900. 195900. 324800.
#  175000. 235400. 342900. 191000. 182700. 257700. 368100. 142000. 224400.
#  232100.]
# Unique values in column STATUS are: [nan 'F' 'E' 'x']
# Unique values in column SYMBOL are: [nan]
# Unique values in column TERMINATED are: [nan]
# Unique values in column DECIMALS are: [0]

# %%
#Dropping the empty columns (columns with 0 non-null count):
df_mortgage = df_mortgage.drop(['SYMBOL', 'TERMINATED'], axis=1)

#Dropping columns that do not contribute information for the analysis:
df_mortgage = df_mortgage.drop(['DGUID', 'Assets and debts', 'Economic family type', 'Statistics', 'Confidence intervals', 
                              'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 
                              'STATUS', 'DECIMALS'], axis=1)

df_mortgage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   REF_DATE   140 non-null    int64
#  1   GEO        140 non-null    object
#  2   Age group  140 non-null    object
#  3   VALUE      103 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.5+ KB

# %%
#Taking a closer look at the "Age group" column:
df_mortgage['Age group'].unique()
# Out:
# array(['All ages', 'Under 65 years', 'Under 35 years', '35 to 44 years',
#        '45 to 54 years', '55 to 64 years', '65 years and older'],
#       dtype=object)

# %%
#For consistency, the "Under 35 years" can be changed to "34 years and younger".
df_mortgage['Age group'] = df_mortgage['Age group'].replace('Under 35 years', '34 years and younger')

df_mortgage
# Out:
#      REF_DATE                          GEO           Age group     VALUE
# 0        1999             Montréal, Quebec            All ages   95300.0
# 1        2005             Montréal, Quebec            All ages  118700.0
# 2        2012             Montréal, Quebec            All ages  160600.0
# 3        2016             Montréal, Quebec            All ages  167000.0
# 4        1999             Montréal, Quebec      Under 65 years   97000.0
# ..        ...                          ...                 ...       ...
# 135      2016  Vancouver, British Columbia      55 to 64 years  232100.0
# 136      1999  Vancouver, British Columbia  65 years and older       NaN
# 137      2005  Vancouver, British Columbia  65 years and older       NaN
# 138      2012  Vancouver, British Columbia  65 years and older       NaN
# 139      2016  Vancouver, British Columbia  65 years and older       NaN
#
# [140 rows x 4 columns]

# %%
#Selecting rows of data which contain information on Toronto, Vancouver, and Calgary markets:

df_toronto_mort = df_mortgage.loc[df_mortgage['GEO'] == 'Toronto, Ontario']
df_vancouver_mort = df_mortgage.loc[df_mortgage['GEO'] == 'Vancouver, British Columbia']
df_calgary_mort = df_mortgage.loc[df_mortgage['GEO'] == 'Calgary, Alberta']

df_mortgage3 = pd.concat([df_toronto_mort, df_vancouver_mort, df_calgary_mort], axis=0)
df_mortgage3
# Out:
#     REF_DATE               GEO           Age group     VALUE
# 28      1999  Toronto, Ontario            All ages  156600.0
# 29      2005  Toronto, Ontario            All ages  194000.0
# 30      2012  Toronto, Ontario            All ages  226000.0
# 31      2016  Toronto, Ontario            All ages  299300.0
# 32      1999  Toronto, Ontario      Under 65 years  157900.0
# ..       ...               ...                 ...       ...
# 79      2016  Calgary, Alberta      55 to 64 years  236500.0
# 80      1999  Calgary, Alberta  65 years and older       NaN
# 81      2005  Calgary, Alberta  65 years and older       NaN
# 82      2012  Calgary, Alberta  65 years and older       NaN
# 83      2016  Calgary, Alberta  65 years and older       NaN
#
# [84 rows x 4 columns]

# %%
#Checking for the number of missing values:
df_mortgage3['VALUE'].isnull().sum()
# Out:
# 20

# %%
#For filling the missing mortgage values, we can take a closer look at each city in each year to see 
#whether a relationship can be identified between mortgage data and different age groups.

#FOR TORONTO:
ax1 = df_toronto_mort.groupby(['Age group', 'REF_DATE']).VALUE.mean().unstack().plot.bar()
ax1.set_title("Average mortgage in Toronto")
ax1.set_xlabel("Year")
ax1.set_ylabel("Average mortgage ($)");

#FOR VANCOUVER:
ax2 = df_vancouver_mort.groupby(['Age group', 'REF_DATE']).VALUE.mean().unstack().plot.bar()
ax2.set_title("Average mortgage in Vancouver")
ax2.set_xlabel("Year")
ax2.set_ylabel("Average mortgage ($)");

#FOR CALGARY:
ax3 = df_calgary_mort.groupby(['Age group', 'REF_DATE']).VALUE.mean().unstack().plot.bar()
ax3.set_title("Average mortgage in Calgary")
ax3.set_xlabel("Year")
ax3.set_ylabel("Average mortgage ($)");

# %%
#As seen in plots, the "65 years and older" category has a high number of missing values for all cities and 
#in all years (except for Toronto in 2016, all other "65 years and older" data are missing). 
#Therefore, this category will be dropped:
df_mort1 = df_mortgage3.loc[df_mortgage['Age group'] != '65 years and older']

#The plots show some trends between mortgage data and age groups and different years that we can use 
#for imputing the missing data.
#For example, older age groups tend to have lower mortgage values. 
#Also, mortgage values show a general increasing trend from 1999 to 2016.
#These values can be fitted to a curve and the missing data can be extrapolated using the parameters for the fit.

#After all data are filled in, the average for all ages (under 65) can be calculated and compared with the available 
#"Under 65 years" column to make sure the predicted data are in an acceptable range.

#Creating a dataframe without the "all ages" and "under 65 years" columns so they are not included in the curve fitting:
#The age groups of "all ages" and "under 65 years" are redundant since the other age groups already cover all ages.
df_mort = df_mort1.loc[(df_mort1['Age group'] != 'All ages') & (df_mort1['Age group'] != 'Under 65 years')]

# %%
#Creating dataframe for curve fitting for Toronto:
df1 = df_mort.loc[(df_mort['GEO'] == 'Toronto, Ontario') & (df_mort['REF_DATE'] == 1999)]
df2 = df_mort.loc[(df_mort['GEO'] == 'Toronto, Ontario') & (df_mort['REF_DATE'] == 2005)]
df3 = df_mort.loc[(df_mort['GEO'] == 'Toronto, Ontario') & (df_mort['REF_DATE'] == 2012)]
df4 = df_mort.loc[(df_mort['GEO'] == 'Toronto, Ontario') & (df_mort['REF_DATE'] == 2016)]

#Creating dataframe for curve fitting for Vancouver:
df5 = df_mort.loc[(df_mort['GEO'] == 'Vancouver, British Columbia') & (df_mort['REF_DATE'] == 1999)]
df6 = df_mort.loc[(df_mort['GEO'] == 'Vancouver, British Columbia') & (df_mort['REF_DATE'] == 2005)]
df7 = df_mort.loc[(df_mort['GEO'] == 'Vancouver, British Columbia') & (df_mort['REF_DATE'] == 2012)]
df8 = df_mort.loc[(df_mort['GEO'] == 'Vancouver, British Columbia') & (df_mort['REF_DATE'] == 2016)]

#Creating dataframe for curve fitting for Calgary:
df9 = df_mort.loc[(df_mort['GEO'] == 'Calgary, Alberta') & (df_mort['REF_DATE'] == 1999)]
df10 = df_mort.loc[(df_mort['GEO'] == 'Calgary, Alberta') & (df_mort['REF_DATE'] == 2005)]
df11 = df_mort.loc[(df_mort['GEO'] == 'Calgary, Alberta') & (df_mort['REF_DATE'] == 2012)]
df12 = df_mort.loc[(df_mort['GEO'] == 'Calgary, Alberta') & (df_mort['REF_DATE'] == 2016)]

for df in (df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12):
    print(df)
    print()
# Out:
#     REF_DATE               GEO             Age group     VALUE
# 36      1999  Toronto, Ontario  34 years and younger  193800.0
# 40      1999  Toronto, Ontario        35 to 44 years  152000.0
# 44      1999  Toronto, Ontario        45 to 54 years  147200.0
# 48      1999  Toronto, Ontario        55 to 64 years  121200.0
#
#     REF_DATE               GEO             Age group     VALUE
# 37      2005  Toronto, Ontario  34 years and younger       NaN
# 41      2005  Toronto, Ontario        35 to 44 years  225500.0
# 45      2005  Toronto, Ontario        45 to 54 years  189200.0
# 49      2005  Toronto, Ontario        55 to 64 years  140000.0
#
#     REF_DATE               GEO             Age group     VALUE
# 38      2012  Toronto, Ontario  34 years and younger  273200.0
# 42      2012  Toronto, Ontario        35 to 44 years  266900.0
# 46      2012  Toronto, Ontario        45 to 54 years  194500.0
# 50      2012  Toronto, Ontario        55 to 64 years  182000.0
#
#     REF_DATE               GEO             Age group     VALUE
# 39      2016  Toronto, Ontario  34 years and younger  337300.0
# 43      2016  Toronto, Ontario        35 to 44 years  328500.0
# 47      2016  Toronto, Ontario        45 to 54 years  283700.0
# 51      2016  Toronto, Ontario        55 to 64 years  266800.0
#
#      REF_DATE                          GEO             Age group     VALUE
# 120      1999  Vancouver, British Columbia  34 years and younger  195900.0
# 124      1999  Vancouver, British Columbia        35 to 44 years  175000.0
# 128      1999  Vancouver, British Columbia        45 to 54 years  191000.0
# 132      1999  Vancouver, British Columbia        55 to 64 years  142000.0
#
#      REF_DATE                          GEO             Age group     VALUE
# 121      2005  Vancouver, British Columbia  34 years and younger       NaN
# 125      2005  Vancouver, British Columbia        35 to 44 years  235400.0
# 129      2005  Vancouver, British Columbia        45 to 54 years  182700.0
# 133      2005  Vancouver, British Columbia        55 to 64 years       NaN
#
#      REF_DATE                          GEO             Age group     VALUE
# 122      2012  Vancouver, British Columbia  34 years and younger  324800.0
# 126      2012  Vancouver, British Columbia        35 to 44 years  342900.0
# 130      2012  Vancouver, British Columbia        45 to 54 years  257700.0
# 134      2012  Vancouver, British Columbia        55 to 64 years  224400.0
#
#      REF_DATE                          GEO             Age group     VALUE
# 123      2016  Vancouver, British Columbia  34 years and younger  324800.0
# 127      2016  Vancouver, British Columbia        35 to 44 years  342900.0
# 131      2016  Vancouver, British Columbia        45 to 54 years  368100.0
# 135      2016  Vancouver, British Columbia        55 to 64 years  232100.0
#
#     REF_DATE               GEO             Age group     VALUE
# 64      1999  Calgary, Alberta  34 years and younger  141700.0
# 68      1999  Calgary, Alberta        35 to 44 years  124200.0
# 72      1999  Calgary, Alberta        45 to 54 years  107800.0
# 76      1999  Calgary, Alberta        55 to 64 years       NaN
#
#     REF_DATE               GEO             Age group     VALUE
# 65      2005  Calgary, Alberta  34 years and younger       NaN
# 69      2005  Calgary, Alberta        35 to 44 years       NaN
# 73      2005  Calgary, Alberta        45 to 54 years  116000.0
# 77      2005  Calgary, Alberta        55 to 64 years       NaN
#
#     REF_DATE               GEO             Age group     VALUE
# 66      2012  Calgary, Alberta  34 years and younger       NaN
# 70      2012  Calgary, Alberta        35 to 44 years  278500.0
# 74      2012  Calgary, Alberta        45 to 54 years  187600.0
# 78      2012  Calgary, Alberta        55 to 64 years       NaN
#
#     REF_DATE               GEO             Age group     VALUE
# 67      2016  Calgary, Alberta  34 years and younger  296900.0
# 71      2016  Calgary, Alberta        35 to 44 years  273100.0
# 75      2016  Calgary, Alberta        45 to 54 years  268200.0
# 79      2016  Calgary, Alberta        55 to 64 years  236500.0

# %%
#For more accurate estimations, curve fitting was done only for dataframes with at least 3 availble values out of 
#the total 5 age groups.

#Therefore, curve fitting for Vancouver in year 2005 and for Calgary in years 2005 and 2012 was not done.

# %%
#For extrapolating the missing data:

from scipy.optimize import curve_fit

#Function to curve fit to the data:
def func(x, a, b, c):
    return a * (x ** 2) + b * x + c

#Initial parameter "guess", just for kicking off the optimization:
guess = (0.5, 0.5, 0.5)

#Curve fitting and extrapolating:
for df in (df1, df2, df3, df5, df7, df8, df9, df12):
    #Creating a copy of data for removing NaNs prior to curve fitting:
    fit_df = df.dropna()

    #Place to store function parameters for each column:
    col_params = {}

    #Curve fit:
    #Getting x and y:
    x = fit_df.index.astype(float).values
    y = fit_df['VALUE'].values
    #Curve fit column and get curve parameters:
    params = curve_fit(func, x, y, guess)
    #Store optimized parameters:
    col_params['VALUE'] = params[0]

    #Extrapolate:
    #Get the index values for NaNs in the column:
    x = df[pd.isnull(df['VALUE'])].index.astype(float).values
    #Extrapolate those points with the fitted function:
    df['VALUE'][x] = func(x, *col_params['VALUE'])
    
    df['Average for under 65'] = df['VALUE'].mean()
    
df_all_mort = pd.concat((df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12), axis=0)
df_all_mort
# Out:
#      REF_DATE                          GEO             Age group     VALUE  \
# 36       1999             Toronto, Ontario  34 years and younger  193800.0
# 40       1999             Toronto, Ontario        35 to 44 years  152000.0
# 44       1999             Toronto, Ontario        45 to 54 years  147200.0
# 48       1999             Toronto, Ontario        55 to 64 years  121200.0
# 37       2005             Toronto, Ontario  34 years and younger  248900.0
# 41       2005             Toronto, Ontario        35 to 44 years  225500.0
# 45       2005             Toronto, Ontario        45 to 54 years  189200.0
# 49       2005             Toronto, Ontario        55 to 64 years  140000.0
# 38       2012             Toronto, Ontario  34 years and younger  273200.0
# 42       2012             Toronto, Ontario        35 to 44 years  266900.0
# 46       2012             Toronto, Ontario        45 to 54 years  194500.0
# 50       2012             Toronto, Ontario        55 to 64 years  182000.0
# 39       2016             Toronto, Ontario  34 years and younger  337300.0
# 43       2016             Toronto, Ontario        35 to 44 years  328500.0
# 47       2016             Toronto, Ontario        45 to 54 years  283700.0
# 51       2016             Toronto, Ontario        55 to 64 years  266800.0
# 120      1999  Vancouver, British Columbia  34 years and younger  195900.0
# 124      1999  Vancouver, British Columbia        35 to 44 years  175000.0
# 128      1999  Vancouver, British Columbia        45 to 54 years  191000.0
# 132      1999  Vancouver, British Columbia        55 to 64 years  142000.0
# 121      2005  Vancouver, British Columbia  34 years and younger       NaN
# 125      2005  Vancouver, British Columbia        35 to 44 years  235400.0
# 129      2005  Vancouver, British Columbia        45 to 54 years  182700.0
# 133      2005  Vancouver, British Columbia        55 to 64 years       NaN
# 122      2012  Vancouver, British Columbia  34 years and younger  324800.0
# 126      2012  Vancouver, British Columbia        35 to 44 years  342900.0
# 130      2012  Vancouver, British Columbia        45 to 54 years  257700.0
# 134      2012  Vancouver, British Columbia        55 to 64 years  224400.0
# 123      2016  Vancouver, British Columbia  34 years and younger  324800.0
# 127      2016  Vancouver, British Columbia        35 to 44 years  342900.0
# 131      2016  Vancouver, British Columbia        45 to 54 years  368100.0
# 135      2016  Vancouver, British Columbia        55 to 64 years  232100.0
# 64       1999             Calgary, Alberta  34 years and younger  141700.0
# 68       1999             Calgary, Alberta        35 to 44 years  124200.0
# 72       1999             Calgary, Alberta        45 to 54 years  107800.0
# 76       1999             Calgary, Alberta        55 to 64 years   92500.0
# 65       2005             Calgary, Alberta  34 years and younger       NaN
# 69       2005             Calgary, Alberta        35 to 44 years       NaN
# 73       2005             Calgary, Alberta        45 to 54 years  116000.0
# 77       2005             Calgary, Alberta        55 to 64 years       NaN
# 66       2012             Calgary, Alberta  34 years and younger       NaN
# 70       2012             Calgary, Alberta        35 to 44 years  278500.0
# 74       2012             Calgary, Alberta        45 to 54 years  187600.0
# 78       2012             Calgary, Alberta        55 to 64 years       NaN
# 67       2016             Calgary, Alberta  34 years and younger  296900.0
# 71       2016             Calgary, Alberta        35 to 44 years  273100.0
# 75       2016             Calgary, Alberta        45 to 54 years  268200.0
# 79       2016             Calgary, Alberta        55 to 64 years  236500.0
#
#      Average for under 65
# 36               153550.0
# 40               153550.0
# 44               153550.0
# 48               153550.0
# 37               200900.0
# 41               200900.0
# 45               200900.0
# 49               200900.0
# 38               229150.0
# 42               229150.0
# 46               229150.0
# 50               229150.0
# 39                    NaN
# 43                    NaN
# 47                    NaN
# 51                    NaN
# 120              175975.0
# 124              175975.0
# 128              175975.0
# 132              175975.0
# 121                   NaN
# 125                   NaN
# 129                   NaN
# 133                   NaN
# 122              287450.0
# 126              287450.0
# 130              287450.0
# 134              287450.0
# 123              316975.0
# 127              316975.0
# 131              316975.0
# 135              316975.0
# 64               116550.0
# 68               116550.0
# 72               116550.0
# 76               116550.0
# 65                    NaN
# 69                    NaN
# 73                    NaN
# 77                    NaN
# 66                    NaN
# 70                    NaN
# 74                    NaN
# 78                    NaN
# 67               268675.0
# 71               268675.0
# 75               268675.0
# 79               268675.0

# %%
#The rows containing missing values for Vancouver in year 2005 and for Calgary in years 2005 and 2012 will be dropped since
#there is not enough available data for an accurate curve fit.
df_all = df_all_mort.dropna(subset=['VALUE'], axis=0)

#Creating a dataframe with the available average values in the dataset for "under 65 years":
df_mort_with_avg = df_mort1.loc[df_mort1['Age group'] == 'Under 65 years']

#The average mortgage values for under 65 years that were obtained by curve fitting will be compared with the 
#available data in the original dataset. For this comparison, the dataframes that were not curve fitted will be dropped.
#The dataframes that were not curve fitted did not have an average calculated in the curve fitting code; therefore,
#the value in their "Average for under 65" column was NaN.
df_curvefitted = df_all.dropna(subset=['Average for under 65'], axis=0)

#Merging the two above dataframes so the averages can be compared:
df_compare = df_curvefitted.merge(df_mort_with_avg, on=['REF_DATE', 'GEO'], how='left')
df_compare.head()
# Out:
#    REF_DATE               GEO           Age group_x   VALUE_x  \
# 0      1999  Toronto, Ontario  34 years and younger  193800.0
# 1      1999  Toronto, Ontario        35 to 44 years  152000.0
# 2      1999  Toronto, Ontario        45 to 54 years  147200.0
# 3      1999  Toronto, Ontario        55 to 64 years  121200.0
# 4      2005  Toronto, Ontario  34 years and younger  248900.0
#
#    Average for under 65     Age group_y   VALUE_y
# 0              153550.0  Under 65 years  157900.0
# 1              153550.0  Under 65 years  157900.0
# 2              153550.0  Under 65 years  157900.0
# 3              153550.0  Under 65 years  157900.0
# 4              200900.0  Under 65 years  199600.0

# %%
#For easier comparison, the average values will be put into a new dataframe.

avg1 = df_compare['VALUE_y']
avg2 = df_compare['Average for under 65']
ref_date = df_compare['REF_DATE']
geo = df_compare['GEO']
df_compare_values = pd.DataFrame({'Year':ref_date, 'City':geo, 'Average from dataset':avg1, 'Average from Calculation':avg2})
df_compare_values = df_compare_values.drop_duplicates(subset=None, keep='first')
df_compare_values
# Out:
#     Year                         City  Average from dataset  \
# 0   1999             Toronto, Ontario              157900.0
# 4   2005             Toronto, Ontario              199600.0
# 8   2012             Toronto, Ontario              232400.0
# 12  1999  Vancouver, British Columbia              180600.0
# 16  2012  Vancouver, British Columbia              294700.0
# 20  2016  Vancouver, British Columbia              331900.0
# 24  1999             Calgary, Alberta              122500.0
# 28  2016             Calgary, Alberta              271600.0
#
#     Average from Calculation
# 0                   153550.0
# 4                   200900.0
# 8                   229150.0
# 12                  175975.0
# 16                  287450.0
# 20                  316975.0
# 24                  116550.0
# 28                  268675.0

# %%
#As seen, the average values calculated from the predicted data are very close to the average values present in the
#original dataset. Therefore, our estimated predictions are in an acceptable range and have not resulted in off average
#values.

#The final cleaned and imputed dataframe with dropped missing values that could not be filled in is:
df_final = df_all.drop(['Average for under 65'], axis=1)
df_final = df_final.reset_index(drop=True)
df_final
# Out:
#     REF_DATE                          GEO             Age group     VALUE
# 0       1999             Toronto, Ontario  34 years and younger  193800.0
# 1       1999             Toronto, Ontario        35 to 44 years  152000.0
# 2       1999             Toronto, Ontario        45 to 54 years  147200.0
# 3       1999             Toronto, Ontario        55 to 64 years  121200.0
# 4       2005             Toronto, Ontario  34 years and younger  248900.0
# 5       2005             Toronto, Ontario        35 to 44 years  225500.0
# 6       2005             Toronto, Ontario        45 to 54 years  189200.0
# 7       2005             Toronto, Ontario        55 to 64 years  140000.0
# 8       2012             Toronto, Ontario  34 years and younger  273200.0
# 9       2012             Toronto, Ontario        35 to 44 years  266900.0
# 10      2012             Toronto, Ontario        45 to 54 years  194500.0
# 11      2012             Toronto, Ontario        55 to 64 years  182000.0
# 12      2016             Toronto, Ontario  34 years and younger  337300.0
# 13      2016             Toronto, Ontario        35 to 44 years  328500.0
# 14      2016             Toronto, Ontario        45 to 54 years  283700.0
# 15      2016             Toronto, Ontario        55 to 64 years  266800.0
# 16      1999  Vancouver, British Columbia  34 years and younger  195900.0
# 17      1999  Vancouver, British Columbia        35 to 44 years  175000.0
# 18      1999  Vancouver, British Columbia        45 to 54 years  191000.0
# 19      1999  Vancouver, British Columbia        55 to 64 years  142000.0
# 20      2005  Vancouver, British Columbia        35 to 44 years  235400.0
# 21      2005  Vancouver, British Columbia        45 to 54 years  182700.0
# 22      2012  Vancouver, British Columbia  34 years and younger  324800.0
# 23      2012  Vancouver, British Columbia        35 to 44 years  342900.0
# 24      2012  Vancouver, British Columbia        45 to 54 years  257700.0
# 25      2012  Vancouver, British Columbia        55 to 64 years  224400.0
# 26      2016  Vancouver, British Columbia  34 years and younger  324800.0
# 27      2016  Vancouver, British Columbia        35 to 44 years  342900.0
# 28      2016  Vancouver, British Columbia        45 to 54 years  368100.0
# 29      2016  Vancouver, British Columbia        55 to 64 years  232100.0
# 30      1999             Calgary, Alberta  34 years and younger  141700.0
# 31      1999             Calgary, Alberta        35 to 44 years  124200.0
# 32      1999             Calgary, Alberta        45 to 54 years  107800.0
# 33      1999             Calgary, Alberta        55 to 64 years   92500.0
# 34      2005             Calgary, Alberta        45 to 54 years  116000.0
# 35      2012             Calgary, Alberta        35 to 44 years  278500.0
# 36      2012             Calgary, Alberta        45 to 54 years  187600.0
# 37      2016             Calgary, Alberta  34 years and younger  296900.0
# 38      2016             Calgary, Alberta        35 to 44 years  273100.0
# 39      2016             Calgary, Alberta        45 to 54 years  268200.0
# 40      2016             Calgary, Alberta        55 to 64 years  236500.0

# %%
fig1 = sns.catplot(x='Age group', y='VALUE', hue='REF_DATE', kind='point', data=df_final)
fig1.set(xlabel='Age group', ylabel='Average mortgage ($)')
fig1._legend.set_title("Year")
fig1.fig.autofmt_xdate();

# %%
#As seen in plot, the general average mortgage trends in the three explored Canadian cities are:

#As age increases, the average mortgage decreases. 
#This mortgage gap between ages has increased over the years. 
#Year 1999 shows the least average mortgage difference between population of under 34 years of age and over 55, 
#while this mortgage gap has significantly grown between the younger and older generations in the other three years.

#The average mortgage values has increased over the years.
#The average mortgage values in 2016 are almost twice as average mortgage values in 1999.

# %%
fig2 = sns.catplot(x='REF_DATE', y='VALUE', hue='GEO', kind='point', data=df_final)
fig2.set(xlabel='Year', ylabel='Average mortgage ($)')
fig2._legend.set_title("City")
fig2.fig.autofmt_xdate();

# %%
#Plot shows that Vancouver has the highest average of mortgage values, followed by Toronto, with Calgary showing the
#lowest amounts of average mortgage values throughout all years investigated here.

#Even though in 2012, the average mortgage values in Calgary slightly pass the average mortgage values of Toronto,
#they fall back to below the average values of both the other two cities in 2016.

#Average mortgage values for Calgary jump to almost double their values from 2005 to 2012, which is the highest rate of
#increase among consequent data points of all cities.

# %%
fig3 = sns.catplot(x='REF_DATE', y='VALUE', hue='Age group', kind='point', data=df_final)
fig3.set(xlabel='Year', ylabel='Average mortgage ($)')
fig3._legend.set_title("Age group")
fig3.fig.autofmt_xdate();

# %%
#As seen in plot, the general trend is decrease of average mortgage values with age increase.

#Even though the average mortgage values for middle age groups (35-44 & 45-54) is almost exactly in the middle of the
#other two age groups in 1999, by 2016 they reach values as high as the youngest age group (34 years and younger) which
#generates a large gap between age groups of under 54 and over 55.

#The average mortgage values for the two younger age groups (34 years and younger & 35-44 years) have been very close to
#each other over the years, especially from 2012 to 2016 which their values almost overlap.
