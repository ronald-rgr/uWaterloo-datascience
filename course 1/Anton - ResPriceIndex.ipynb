# %%
#Importing packages
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

#Importing visualization packages
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.ticker import ScalarFormatter

import seaborn as sns

# %%
#Importing the data as panda dataframe
df_rpi = pd.read_csv('csv/dbResPriceIndex2017-2020.csv')

df_rpi.head()
# Out:
#   REF_DATE               GEO         DGUID         Building type  \
# 0  2017-01  Montréal, Quebec  2016S0503462  Total, building type
# 1  2017-04  Montréal, Quebec  2016S0503462  Total, building type
# 2  2017-07  Montréal, Quebec  2016S0503462  Total, building type
# 3  2017-10  Montréal, Quebec  2016S0503462  Total, building type
# 4  2018-01  Montréal, Quebec  2016S0503462  Total, building type
#
#           Construction type              UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0  Total, construction type  Index, 2017=100     373         units          0
# 1  Total, construction type  Index, 2017=100     373         units          0
# 2  Total, construction type  Index, 2017=100     373         units          0
# 3  Total, construction type  Index, 2017=100     373         units          0
# 4  Total, construction type  Index, 2017=100     373         units          0
#
#         VECTOR COORDINATE  VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  v1073542625      2.1.1   98.1    NaN     NaN         NaN         1
# 1  v1073542625      2.1.1   99.3    NaN     NaN         NaN         1
# 2  v1073542625      2.1.1  100.6    NaN     NaN         NaN         1
# 3  v1073542625      2.1.1  102.0    NaN     NaN         NaN         1
# 4  v1073542625      2.1.1  102.0    NaN     NaN         NaN         1

# %%
# Overview of the data
df_rpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   REF_DATE           702 non-null    object
#  1   GEO                702 non-null    object
#  2   DGUID              702 non-null    object
#  3   Building type      702 non-null    object
#  4   Construction type  702 non-null    object
#  5   UOM                702 non-null    object
#  6   UOM_ID             702 non-null    int64
#  7   SCALAR_FACTOR      702 non-null    object
#  8   SCALAR_ID          702 non-null    int64
#  9   VECTOR             702 non-null    object
#  10  COORDINATE         702 non-null    object
#  11  VALUE              702 non-null    float64
#  12  STATUS             35 non-null     object
#  13  SYMBOL             0 non-null      float64
#  14  TERMINATED         0 non-null      float64
#  15  DECIMALS           702 non-null    int64
# dtypes: float64(3), int64(3), object(10)
# memory usage: 87.9+ KB

# %%
#Dropping the empty columns (columns with 0 non-null count):
df_rpi = df_rpi.drop(['SYMBOL', 'TERMINATED'], axis=1)

#Dropping columns that do not contribute information for the analysis:
df_rpi = df_rpi.drop(['STATUS', 'DGUID', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 
                                    'VECTOR', 'COORDINATE', 'DECIMALS'], axis=1)

df_rpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   REF_DATE           702 non-null    object
#  1   GEO                702 non-null    object
#  2   Building type      702 non-null    object
#  3   Construction type  702 non-null    object
#  4   VALUE              702 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 27.5+ KB

# %%
df_rpi
# Out:
#     REF_DATE                         GEO          Building type  \
# 0    2017-01            Montréal, Quebec   Total, building type
# 1    2017-04            Montréal, Quebec   Total, building type
# 2    2017-07            Montréal, Quebec   Total, building type
# 3    2017-10            Montréal, Quebec   Total, building type
# 4    2018-01            Montréal, Quebec   Total, building type
# ..       ...                         ...                    ...
# 697  2019-01  Victoria, British Columbia  Condominium apartment
# 698  2019-04  Victoria, British Columbia  Condominium apartment
# 699  2019-07  Victoria, British Columbia  Condominium apartment
# 700  2019-10  Victoria, British Columbia  Condominium apartment
# 701  2020-01  Victoria, British Columbia  Condominium apartment
#
#             Construction type  VALUE
# 0    Total, construction type   98.1
# 1    Total, construction type   99.3
# 2    Total, construction type  100.6
# 3    Total, construction type  102.0
# 4    Total, construction type  102.0
# ..                        ...    ...
# 697                    Resale  107.5
# 698                    Resale  113.1
# 699                    Resale  112.7
# 700                    Resale  113.5
# 701                    Resale  113.6
#
# [702 rows x 5 columns]

# %%
# Get the unique GEO values
df_rpi.GEO.unique()
# Out:
# array(['Montréal, Quebec',
#        'Ottawa-Gatineau, Ontario part, Ontario/Quebec',
#        'Toronto, Ontario', 'Calgary, Alberta',
#        'Vancouver, British Columbia', 'Victoria, British Columbia'],
#       dtype=object)

# %%
# Filter to only show Toronto, Vancouver and Calgary
df_rpi2 = df_rpi[df_rpi['GEO'].isin(['Calgary, Alberta', 'Toronto, Ontario','Vancouver, British Columbia'])]
df_rpi2
# Out:
#     REF_DATE                          GEO          Building type  \
# 234  2017-01             Toronto, Ontario   Total, building type
# 235  2017-04             Toronto, Ontario   Total, building type
# 236  2017-07             Toronto, Ontario   Total, building type
# 237  2017-10             Toronto, Ontario   Total, building type
# 238  2018-01             Toronto, Ontario   Total, building type
# ..       ...                          ...                    ...
# 580  2019-01  Vancouver, British Columbia  Condominium apartment
# 581  2019-04  Vancouver, British Columbia  Condominium apartment
# 582  2019-07  Vancouver, British Columbia  Condominium apartment
# 583  2019-10  Vancouver, British Columbia  Condominium apartment
# 584  2020-01  Vancouver, British Columbia  Condominium apartment
#
#             Construction type  VALUE
# 234  Total, construction type   95.3
# 235  Total, construction type  103.3
# 236  Total, construction type  101.9
# 237  Total, construction type   99.5
# 238  Total, construction type  100.0
# ..                        ...    ...
# 580                    Resale  113.5
# 581                    Resale  111.4
# 582                    Resale  109.0
# 583                    Resale  110.0
# 584                    Resale  111.9
#
# [351 rows x 5 columns]

# %%
#Grouping by quarter and city to better understand the data structure
df_rpi2.groupby(['REF_DATE', 'GEO','Building type','Construction type']).VALUE.mean()
# Out:
# REF_DATE  GEO                          Building type          Construction type
# 2017-01   Calgary, Alberta             Condominium apartment  New build                   100.9
#                                                               Resale                      100.4
#                                                               Total, construction type    100.7
#                                        House                  New build                    99.7
#                                                               Resale                       98.8
#                                                                                           ...
# 2020-01   Vancouver, British Columbia  House                  Resale                      102.8
#                                                               Total, construction type    102.4
#                                        Total, building type   New build                   103.7
#                                                               Resale                      105.1
#                                                               Total, construction type    104.6
# Name: VALUE, Length: 351, dtype: float64

# %%
# We should analyze prices for condominiums and houses separately, disregarding between new build and resale
df_rpi3 = df_rpi2[df_rpi2['Construction type'].isin(['Total, construction type'])]
df_rpi3
df_condo = df_rpi3[df_rpi3['Building type'].isin(['Condominium apartment'])]
df_house = df_rpi3[df_rpi3['Building type'].isin(['House'])]
# Out:
#     REF_DATE                          GEO          Building type  \
# 312  2017-01             Toronto, Ontario  Condominium apartment
# 313  2017-04             Toronto, Ontario  Condominium apartment
# 314  2017-07             Toronto, Ontario  Condominium apartment
# 315  2017-10             Toronto, Ontario  Condominium apartment
# 316  2018-01             Toronto, Ontario  Condominium apartment
# 317  2018-04             Toronto, Ontario  Condominium apartment
# 318  2018-07             Toronto, Ontario  Condominium apartment
# 319  2018-10             Toronto, Ontario  Condominium apartment
# 320  2019-01             Toronto, Ontario  Condominium apartment
# 321  2019-04             Toronto, Ontario  Condominium apartment
# 322  2019-07             Toronto, Ontario  Condominium apartment
# 323  2019-10             Toronto, Ontario  Condominium apartment
# 324  2020-01             Toronto, Ontario  Condominium apartment
# 429  2017-01             Calgary, Alberta  Condominium apartment
# 430  2017-04             Calgary, Alberta  Condominium apartment
# 431  2017-07             Calgary, Alberta  Condominium apartment
# 432  2017-10             Calgary, Alberta  Condominium apartment
# 433  2018-01             Calgary, Alberta  Condominium apartment
# 434  2018-04             Calgary, Alberta  Condominium apartment
# 435  2018-07             Calgary, Alberta  Condominium apartment
# 436  2018-10             Calgary, Alberta  Condominium apartment
# 437  2019-01             Calgary, Alberta  Condominium apartment
# 438  2019-04             Calgary, Alberta  Condominium apartment
# 439  2019-07             Calgary, Alberta  Condominium apartment
# 440  2019-10             Calgary, Alberta  Condominium apartment
# 441  2020-01             Calgary, Alberta  Condominium apartment
# 546  2017-01  Vancouver, British Columbia  Condominium apartment
# 547  2017-04  Vancouver, British Columbia  Condominium apartment
# 548  2017-07  Vancouver, British Columbia  Condominium apartment
# 549  2017-10  Vancouver, British Columbia  Condominium apartment
# 550  2018-01  Vancouver, British Columbia  Condominium apartment
# 551  2018-04  Vancouver, British Columbia  Condominium apartment
# 552  2018-07  Vancouver, British Columbia  Condominium apartment
# 553  2018-10  Vancouver, British Columbia  Condominium apartment
# 554  2019-01  Vancouver, British Columbia  Condominium apartment
# 555  2019-04  Vancouver, British Columbia  Condominium apartment
# 556  2019-07  Vancouver, British Columbia  Condominium apartment
# 557  2019-10  Vancouver, British Columbia  Condominium apartment
# 558  2020-01  Vancouver, British Columbia  Condominium apartment
#
#             Construction type  VALUE
# 312  Total, construction type   93.5
# 313  Total, construction type  101.3
# 314  Total, construction type  102.3
# 315  Total, construction type  103.0
# 316  Total, construction type  104.9
# 317  Total, construction type  107.6
# 318  Total, construction type  109.0
# 319  Total, construction type  111.4
# 320  Total, construction type  112.1
# 321  Total, construction type  114.2
# 322  Total, construction type  114.1
# 323  Total, construction type  118.9
# 324  Total, construction type  124.6
# 429  Total, construction type  100.7
# 430  Total, construction type  101.4
# 431  Total, construction type  100.1
# 432  Total, construction type   97.7
# 433  Total, construction type   95.8
# 434  Total, construction type   93.7
# 435  Total, construction type   93.5
# 436  Total, construction type   90.2
# 437  Total, construction type   87.7
# 438  Total, construction type   86.1
# 439  Total, construction type   85.7
# 440  Total, construction type   83.3
# 441  Total, construction type   82.7
# 546  Total, construction type   91.6
# 547  Total, construction type   96.7
# 548  Total, construction type  103.3
# 549  Total, construction type  108.4
# 550  Total, construction type  109.9
# 551  Total, construction type  111.3
# 552  Total, construction type  111.9
# 553  Total, construction type  110.3
# 554  Total, construction type  111.9
# 555  Total, construction type  110.0
# 556  Total, construction type  107.7
# 557  Total, construction type  108.1
# 558  Total, construction type  110.6

# %%
# Plot condominium prices by quarter for each city
fig1 = sns.catplot(x='REF_DATE', y='VALUE', hue='GEO', kind='point', data=df_condo, height=5, aspect=10/5)
fig1.set(xlabel='Quarter', ylabel='Price by Index')
fig1._legend.set_title("City")
fig1.fig.autofmt_xdate();

# %%
# Plot house prices by quarter for each city
fig1 = sns.catplot(x='REF_DATE', y='VALUE', hue='GEO', kind='point', data=df_house, height=5, aspect=10/5)
fig1.set(xlabel='Quarter', ylabel='Price by Index')
fig1._legend.set_title("City")
fig1.fig.autofmt_xdate();

# %% [markdown]
# There is a clear distinction in trends between Condominiums and House prices. In Toronto and Vancouver, there has been a persistent upward trends since Q1 2017. Vancouver has reached a more stabilized level, while Toronto has not shown any evidence of stabilization. Meanwhile, Condominium prices in Calgary have been steadily decreasing in the same time period. House prices peaked between 2017 and 2018 in Vancouver and Toronto and experienced a slight decline since then. However, they have gradually recovered and are close to 2017 levels once again. Calgary house prices decreased, unsurprisingly, however not at the same pace as condominium prices.
