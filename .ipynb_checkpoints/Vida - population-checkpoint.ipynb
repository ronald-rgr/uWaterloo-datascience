# %%
#Importing packages
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

#Importing visualization packages
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.ticker import ScalarFormatter

import seaborn as sns

# %%
#Importing the data as panda dataframe
df_population = pd.read_csv('dbPopEstimatesByCMA2009-2019.csv')

df_population.head()
# Out:
#    REF_DATE                     GEO         DGUID         Sex Age group  \
# 0      2009  Montréal (CMA), Quebec  2016S0503462  Both sexes  All ages
# 1      2010  Montréal (CMA), Quebec  2016S0503462  Both sexes  All ages
# 2      2011  Montréal (CMA), Quebec  2016S0503462  Both sexes  All ages
# 3      2012  Montréal (CMA), Quebec  2016S0503462  Both sexes  All ages
# 4      2013  Montréal (CMA), Quebec  2016S0503462  Both sexes  All ages
#
#        UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE    VALUE  \
# 0  Persons     249         units          0  v1060785691     44.1.1  3907597
# 1  Persons     249         units          0  v1060785691     44.1.1  3953773
# 2  Persons     249         units          0  v1060785691     44.1.1  3994492
# 3  Persons     249         units          0  v1060785691     44.1.1  4031655
# 4  Persons     249         units          0  v1060785691     44.1.1  4066332
#
#    STATUS  SYMBOL  TERMINATED  DECIMALS
# ...

# %%
#Quick look at the data:
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   REF_DATE       66 non-null     int64
#  1   GEO            66 non-null     object
#  2   DGUID          66 non-null     object
#  3   Sex            66 non-null     object
#  4   Age group      66 non-null     object
#  5   UOM            66 non-null     object
#  6   UOM_ID         66 non-null     int64
#  7   SCALAR_FACTOR  66 non-null     object
#  8   SCALAR_ID      66 non-null     int64
#  9   VECTOR         66 non-null     object
#  10  COORDINATE     66 non-null     object
#  11  VALUE          66 non-null     int64
#  12  STATUS         0 non-null      float64
#  13  SYMBOL         0 non-null      float64
#  14  TERMINATED     0 non-null      float64
#  15  DECIMALS       66 non-null     int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 8.4+ KB

# %%
#Dropping the empty columns (columns with 0 non-null count):
df_population = df_population.drop(['STATUS', 'SYMBOL', 'TERMINATED'], axis=1)

#Dropping columns that do not contribute information for the analysis:
df_population = df_population.drop(['DGUID', 'Sex', 'Age group', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 
                                    'VECTOR', 'COORDINATE', 'DECIMALS'], axis=1)

df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   REF_DATE  66 non-null     int64
#  1   GEO       66 non-null     object
#  2   VALUE     66 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.7+ KB

# %%
df_population
# Out:
#     REF_DATE                                GEO    VALUE
# 0       2009             Montréal (CMA), Quebec  3907597
# 1       2010             Montréal (CMA), Quebec  3953773
# 2       2011             Montréal (CMA), Quebec  3994492
# 3       2012             Montréal (CMA), Quebec  4031655
# 4       2013             Montréal (CMA), Quebec  4066332
# ..       ...                                ...      ...
# 61      2015  Vancouver (CMA), British Columbia  2544484
# 62      2016  Vancouver (CMA), British Columbia  2582202
# 63      2017  Vancouver (CMA), British Columbia  2612874
# 64      2018  Vancouver (CMA), British Columbia  2652306
# 65      2019  Vancouver (CMA), British Columbia  2691351
#
# [66 rows x 3 columns]

# %%
#Grouping the population by year and city:
df_population.groupby(['REF_DATE', 'GEO']).VALUE.mean()
# Out:
# REF_DATE  GEO
# 2009      Calgary (CMA), Alberta                     1220700
#           Edmonton (CMA), Alberta                    1163333
#           Montréal (CMA), Quebec                     3907597
#           Ottawa - Gatineau (CMA), Ontario/Quebec    1246116
#           Toronto (CMA), Ontario                     5588312
#                                                       ...
# 2019      Edmonton (CMA), Alberta                    1447143
#           Montréal (CMA), Quebec                     4318505
#           Ottawa - Gatineau (CMA), Ontario/Quebec    1441118
#           Toronto (CMA), Ontario                     6471850
#           Vancouver (CMA), British Columbia          2691351
# Name: VALUE, Length: 66, dtype: int64

# %%
fig1 = sns.catplot(x='REF_DATE', y='VALUE', hue='GEO', kind='bar', data=df_population, height=5, aspect=10/5)
fig1.set(xlabel='Year', ylabel='Population')
fig1._legend.set_title("City")
fig1.fig.autofmt_xdate();

# %% [markdown]
# As seen, for all years investigated in this analysis, Toronto, Montreal, and Vancouver are the most populated Canadian cities.

# %% [markdown]
# For exploring the changes of population over each year, the diff() function was used as below:

# %%
df_population['Diff'] = df_population['VALUE'].diff()
df_population

#The diff() function calculates changes in values compared to their previous row. The "2009" rows can be 
#dropped since their preceding rows of 2008 are not present in the dataframe, and therefore their calculated diff() 
#is meaningless in the context of our analysis).
df_change = df_population.loc[df_population['REF_DATE'] != 2009].reset_index(drop=True)
df_change
# Out:
#     REF_DATE                                      GEO    VALUE      Diff
# 0       2010                   Montréal (CMA), Quebec  3953773   46176.0
# 1       2011                   Montréal (CMA), Quebec  3994492   40719.0
# 2       2012                   Montréal (CMA), Quebec  4031655   37163.0
# 3       2013                   Montréal (CMA), Quebec  4066332   34677.0
# 4       2014                   Montréal (CMA), Quebec  4093501   27169.0
# 5       2015                   Montréal (CMA), Quebec  4109712   16211.0
# 6       2016                   Montréal (CMA), Quebec  4140425   30713.0
# 7       2017                   Montréal (CMA), Quebec  4190786   50361.0
# 8       2018                   Montréal (CMA), Quebec  4253300   62514.0
# 9       2019                   Montréal (CMA), Quebec  4318505   65205.0
# 10      2010  Ottawa - Gatineau (CMA), Ontario/Quebec  1268687   22571.0
# 11      2011  Ottawa - Gatineau (CMA), Ontario/Quebec  1288388   19701.0
# ...

# %%
fig2 = sns.catplot(x='REF_DATE', y='Diff', hue='GEO', kind='point', data=df_change, height=5, aspect=10/5)
fig2.set(xlabel='Year', ylabel='Population growth')
fig2._legend.set_title("City")
fig2.fig.autofmt_xdate();

# %% [markdown]
# For investigating the percentage change of population in the six cities, the percentage change for each city in each year is calculated and is added as a column at the end of the dataframe:

# %%
df_population['Percent_Change'] = df_population['VALUE'].pct_change()

#The pct_change() function calculates changes in values compared to their previous row. The "2009" rows can be 
#dropped since their preceding rows of 2008 are not present in the dataframe, and therefore their calculated pct_change() 
#is meaningless in the context of our analysis).
df_growth = df_population.loc[df_population['REF_DATE'] != 2009].reset_index(drop=True)
df_growth['Percent_Changex100'] = df_growth['Percent_Change']*100 
df_growth
# Out:
#     REF_DATE                                      GEO    VALUE      Diff  \
# 0       2010                   Montréal (CMA), Quebec  3953773   46176.0
# 1       2011                   Montréal (CMA), Quebec  3994492   40719.0
# 2       2012                   Montréal (CMA), Quebec  4031655   37163.0
# 3       2013                   Montréal (CMA), Quebec  4066332   34677.0
# 4       2014                   Montréal (CMA), Quebec  4093501   27169.0
# 5       2015                   Montréal (CMA), Quebec  4109712   16211.0
# 6       2016                   Montréal (CMA), Quebec  4140425   30713.0
# 7       2017                   Montréal (CMA), Quebec  4190786   50361.0
# 8       2018                   Montréal (CMA), Quebec  4253300   62514.0
# 9       2019                   Montréal (CMA), Quebec  4318505   65205.0
# 10      2010  Ottawa - Gatineau (CMA), Ontario/Quebec  1268687   22571.0
# 11      2011  Ottawa - Gatineau (CMA), Ontario/Quebec  1288388   19701.0
# ...

# %%
fig3 = sns.catplot(x='REF_DATE', y='Percent_Changex100', hue='GEO', kind='point', data=df_growth, height=5, aspect=10/5)
fig3.set(xlabel='Year', ylabel='Population growth rate (%)')
fig3._legend.set_title("City")
fig3.fig.autofmt_xdate();

# %%
#Grouping by city:
df_group = df_growth.groupby(['GEO']).Percent_Changex100.mean().reset_index()
df_group
# Out:
#                                        GEO  Percent_Changex100
# 0                   Calgary (CMA), Alberta            2.183653
# 1                  Edmonton (CMA), Alberta            2.208155
# 2                   Montréal (CMA), Quebec            1.005461
# 3  Ottawa - Gatineau (CMA), Ontario/Quebec            1.465587
# 4                   Toronto (CMA), Ontario            1.479297
# 5        Vancouver (CMA), British Columbia            1.577565

# %% [markdown]
# As seen, among the top three most populated cities (Toronto, Montreal, and Vancouver), Vancouver has the highest growth rate (1.6%) while Toronto and Montreal have growth rates of 1.5% and 1.0%, respectively.
